# %% [markdown]
# ## Netflix Stock Market detection

# %%
# Machine learning
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score


# For data manipulation
import pandas as pd
import numpy as np

# To plot
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')

# To ignore warnings
import warnings
warnings.filterwarnings("ignore")
# Out:
# <ipython-input-1-ecc59adf5d07>:11: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error,r2_score

# %%
# Read the csv file using read_csv
# method of pandas
df = pd.read_csv('/content/sample_data/NFLX.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
# Changes The Date column as index columns
df.index = pd.to_datetime(df['Date'])
df

# drop The original date column
df = df.drop(['Date'], axis='columns')
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...                ...         ...         ...         ...         ...
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# 2018-02-07   8981500
# 2018-02-08   9306700
# 2018-02-09  16906900
# ...              ...
# 2022-01-31  20047500
# 2022-02-01  22542300
# 2022-02-02  14346000
# 2022-02-03   9905200
# 2022-02-04   7782400
#
# [1009 rows x 6 columns]

# %%
# Create predictor variables
df['Open-Close'] = df.Open - df.Close
df['High-Low'] = df.High - df.Low

# Store all predictor variables in a variable X
X = df[['Open-Close', 'High-Low']]
X.head()
# Out:
#             Open-Close   High-Low
# Date
# 2018-02-05    7.740005  17.869995
# 2018-02-06  -18.020004  21.700012
# 2018-02-07    2.019989   8.120025
# 2018-02-08   16.979981  17.619995
# 2018-02-09    4.380005  19.690002

# %%
# Target variables
y = np.where(df['Close'].shift(-1) > df['Close'], 1, 0)
y
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
split_percentage = 0.8
split = int(split_percentage*len(df))

# Train data set
X_train = X[:split]
y_train = y[:split]

# Test data set
X_test = X[split:]
y_test = y[split:]

# %%
# Support vector classifier
cls = SVC().fit(X_train, y_train)

# %%
df['Predicted_Signal'] = cls.predict(X)
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume  Open-Close   High-Low  Predicted_Signal    Return  \
# Date
# 2022-01-31  20047500  -25.170014  29.500000                 0  0.111302
# 2022-02-01  22542300  -24.170014  32.940002                 0  0.070211
# 2022-02-02  14346000   18.769989  25.500000                 1 -0.060486
# 2022-02-03   9905200   15.839996  24.980011                 1 -0.055602
# 2022-02-04   7782400   -2.860015  16.129974                 1  0.011267
#
#             Strategy_Return   Cum_Ret  Cum_Strategy
# Date
# 2022-01-31         0.111302  0.872051      1.401256
# 2022-02-01         0.000000  0.942262      1.401256
# 2022-02-02        -0.000000  0.881776      1.401256
# 2022-02-03        -0.055602  0.826174      1.345654
# 2022-02-04         0.011267  0.837441      1.356921

# %%
# Calculate daily returns
df['Return'] = df.Close.pct_change()

# %%
# Calculate strategy returns
df['Strategy_Return'] = df.Return *df.Predicted_Signal.shift(1)

# %%
# Calculate Cumulutive returns
df['Cum_Ret'] = df['Return'].cumsum()
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...                ...         ...         ...         ...         ...
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume  Open-Close   High-Low  Predicted_Signal    Return  \
# Date
# 2018-02-05  11896100    7.740005  17.869995                 1       NaN
# 2018-02-06  12595800  -18.020004  21.700012                 0  0.045072
# 2018-02-07   8981500    2.019989   8.120025                 1 -0.004366
# 2018-02-08   9306700   16.979981  17.619995                 1 -0.054657
# 2018-02-09  16906900    4.380005  19.690002                 1 -0.002519
# ...              ...         ...        ...               ...       ...
# 2022-01-31  20047500  -25.170014  29.500000                 0  0.111302
# 2022-02-01  22542300  -24.170014  32.940002                 0  0.070211
# 2022-02-02  14346000   18.769989  25.500000                 1 -0.060486
# 2022-02-03   9905200   15.839996  24.980011                 1 -0.055602
# 2022-02-04   7782400   -2.860015  16.129974                 1  0.011267
#
#             Strategy_Return   Cum_Ret
# Date
# 2018-02-05              NaN       NaN
# 2018-02-06         0.045072  0.045072
# 2018-02-07        -0.000000  0.040706
# 2018-02-08        -0.054657 -0.013950
# 2018-02-09        -0.002519 -0.016469
# ...                     ...       ...
# 2022-01-31         0.111302  0.872051
# 2022-02-01         0.000000  0.942262
# 2022-02-02        -0.000000  0.881776
# 2022-02-03        -0.055602  0.826174
# 2022-02-04         0.011267  0.837441
#
# [1009 rows x 12 columns]

# %%
# Plot Strategy Cumulative returns
df['Cum_Strategy'] = df['Strategy_Return'].cumsum()
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...                ...         ...         ...         ...         ...
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume  Open-Close   High-Low  Predicted_Signal    Return  \
# Date
# 2018-02-05  11896100    7.740005  17.869995                 1       NaN
# 2018-02-06  12595800  -18.020004  21.700012                 0  0.045072
# 2018-02-07   8981500    2.019989   8.120025                 1 -0.004366
# 2018-02-08   9306700   16.979981  17.619995                 1 -0.054657
# 2018-02-09  16906900    4.380005  19.690002                 1 -0.002519
# ...              ...         ...        ...               ...       ...
# 2022-01-31  20047500  -25.170014  29.500000                 0  0.111302
# 2022-02-01  22542300  -24.170014  32.940002                 0  0.070211
# 2022-02-02  14346000   18.769989  25.500000                 1 -0.060486
# 2022-02-03   9905200   15.839996  24.980011                 1 -0.055602
# 2022-02-04   7782400   -2.860015  16.129974                 1  0.011267
#
#             Strategy_Return   Cum_Ret  Cum_Strategy
# Date
# 2018-02-05              NaN       NaN           NaN
# 2018-02-06         0.045072  0.045072      0.045072
# 2018-02-07        -0.000000  0.040706      0.045072
# 2018-02-08        -0.054657 -0.013950     -0.009585
# 2018-02-09        -0.002519 -0.016469     -0.012104
# ...                     ...       ...           ...
# 2022-01-31         0.111302  0.872051      1.401256
# 2022-02-01         0.000000  0.942262      1.401256
# 2022-02-02        -0.000000  0.881776      1.401256
# 2022-02-03        -0.055602  0.826174      1.345654
# 2022-02-04         0.011267  0.837441      1.356921
#
# [1009 rows x 13 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(df['Cum_Ret'],color='red')
plt.plot(df['Cum_Strategy'],color='blue')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(df[['Open-Close', 'High-Low']], df['Close'])

y_pred = model.predict(X_test) # Generate predictions

plt.scatter(y_pred, y_test, color='red', marker='o')
plt.scatter(y_test, y_test, color='blue')
plt.plot(y_test, y_test, color='lime')
